# %% [markdown]
# <a href="https://colab.research.google.com/github/kitlapp/Telco_ML/blob/main/read_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://github.com/kitlapp/Telco_ML/raw/main/ml_ready_dataset.parquet"
df = pd.read_parquet(url, engine="pyarrow")  # or fastparquet
# Out:
#    Is_Churned  Total_Charges  Avg_Monthly_Charge  Tenure  Is_Male  Is_Senior  \
# 0       False          29.85               29.85       1    False      False
# 1       False        1889.50               55.57      34     True      False
# 2        True         108.15               54.08       2     True      False
# 3       False        1840.75               40.91      45     True      False
# 4        True         151.65               75.82       2    False      False
#
#    Is_Married  Has_Dependents  Has_PhoneService  Is_PaperlessBilling  ...  \
# 0        True           False             False                 True  ...
# 1       False           False              True                False  ...
# 2       False           False              True                 True  ...
# 3       False           False             False                False  ...
# 4       False           False              True                 True  ...
#
# ...

# %%
df.head()
# Out:
#    Is_Churned  Total_Charges  Avg_Monthly_Charge  Tenure  Is_Male  Is_Senior  \
# 0       False          29.85               29.85       1    False      False
# 1       False        1889.50               55.57      34     True      False
# 2        True         108.15               54.08       2     True      False
# 3       False        1840.75               40.91      45     True      False
# 4        True         151.65               75.82       2    False      False
#
#    Is_Married  Has_Dependents  Has_PhoneService  Is_PaperlessBilling  ...  \
# 0        True           False             False                 True  ...
# 1       False           False              True                False  ...
# 2       False           False              True                 True  ...
# 3       False           False             False                False  ...
# 4       False           False              True                 True  ...
#
# ...

# %%
df.shape
# Out:
# (7043, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Is_Churned                        7043 non-null   bool
#  1   Total_Charges                     7043 non-null   float64
#  2   Avg_Monthly_Charge                7043 non-null   float64
#  3   Tenure                            7043 non-null   int64
#  4   Is_Male                           7043 non-null   bool
#  5   Is_Senior                         7043 non-null   bool
#  6   Is_Married                        7043 non-null   bool
#  7   Has_Dependents                    7043 non-null   bool
#  8   Has_PhoneService                  7043 non-null   bool
#  9   Is_PaperlessBilling               7043 non-null   bool
#  10  Has_OnlineSecurity_No             7043 non-null   bool
#  11  Has_OnlineSecurity_NoInternet     7043 non-null   bool
# ...
